# %% [markdown]
# #1. Импортируем нужные библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %matplotlib inline

# %% [markdown]
# #2. Загрузка датасета

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #3. Oценка данных

# %%
# выведем размерность нашего датасета:
titanic_df.shape
# Out:
# (891, 12)

# %%
# выведем типы данных:
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# выведем основные статистические показатели:
titanic_df.describe().round(3)
# Out:
#        PassengerId  Survived   Pclass      Age    SibSp    Parch     Fare
# count      891.000   891.000  891.000  714.000  891.000  891.000  891.000
# mean       446.000     0.384    2.309   29.699    0.523    0.382   32.204
# std        257.354     0.487    0.836   14.526    1.103    0.806   49.693
# min          1.000     0.000    1.000    0.420    0.000    0.000    0.000
# 25%        223.500     0.000    2.000   20.125    0.000    0.000    7.910
# 50%        446.000     0.000    3.000   28.000    0.000    0.000   14.454
# 75%        668.500     1.000    3.000   38.000    1.000    0.000   31.000
# max        891.000     1.000    3.000   80.000    8.000    6.000  512.329

# %% [markdown]
# #4. Feature Engineering:

# %% [markdown]
# ##4.1. Обработка категориальных признаков и создание новых признаков из уже существующих

# %%
#Создаем столбец с фамилией:
titanic_df["Family"] = titanic_df["Name"].apply(lambda s: s.split(",")[0])
titanic_df.reset_index(drop=True,inplace=True)
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     Family
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# 4      0            373450   8.0500   NaN        S      Allen

# %%
print('Family: ', titanic_df.Family.unique(),'\n',
    'Embarked: ', titanic_df.Embarked.unique(),'\n',
      'Sex: ', titanic_df.Sex.unique(),'\n',
      'Age: ', titanic_df.Age.unique())
# Out:
# Family:  ['Braund' 'Cumings' 'Heikkinen' 'Futrelle' 'Allen' 'Moran' 'McCarthy'
#  'Palsson' 'Johnson' 'Nasser' 'Sandstrom' 'Bonnell' 'Saundercock'
#  'Andersson' 'Vestrom' 'Hewlett' 'Rice' 'Williams' 'Vander Planke'
#  'Masselmani' 'Fynney' 'Beesley' 'McGowan' 'Sloper' 'Asplund' 'Emir'
#  'Fortune' "O'Dwyer" 'Todoroff' 'Uruchurtu' 'Spencer' 'Glynn' 'Wheadon'
#  'Meyer' 'Holverson' 'Mamee' 'Cann' 'Nicola-Yarred' 'Ahlin' 'Turpin'
#  'Kraeff' 'Laroche' 'Devaney' 'Rogers' 'Lennon' "O'Driscoll" 'Samaan'
#  'Arnold-Franchi' 'Panula' 'Nosworthy' 'Harper' 'Faunthorpe' 'Ostby'
#  'Woolner' 'Rugg' 'Novel' 'West' 'Goodwin' 'Sirayanian' 'Icard' 'Harris'
#  'Skoog' 'Stewart' 'Moubarek' 'Nye' 'Crease' 'Kink' 'Jenkin' 'Hood'
#  'Chronopoulos' 'Bing' 'Moen' 'Staneff' 'Moutal' 'Caldwell' 'Dowdell'
#  'Waelens' 'Sheerlinck' 'McDermott' 'Carrau' 'Ilett' 'Backstrom' 'Ford'
#  'Slocovski' 'Celotti' 'Christmann' 'Andreasson' 'Chaffee' 'Dean' 'Coxon'
#  'Shorney' 'Goldschmidt' 'Greenfield' 'Doling' 'Kantor' 'Petranec'
#  'Petroff' 'White' 'Johansson' 'Gustafsson' 'Mionoff' 'Salkjelsvik' 'Moss'
#  'Rekic' 'Porter' 'Zabour' 'Barton' 'Jussila' 'Attalah' 'Pekoniemi'
#  'Connors' 'Baxter' 'Hickman' 'Moore' 'Webber' 'McMahon' 'Madsen' 'Peter'
#  'Ekstrom' 'Drazenoic' 'Coelho' 'Robins' 'Weisz' 'Sobey' 'Richard'
#  'Newsom' 'Osen' 'Giglio' 'Boulos' 'Nysten' 'Hakkarainen' 'Burke' 'Andrew'
#  'Nicholls' 'Navratil' 'Byles' 'Bateman' 'Pears' 'Meo' 'van Billiard'
#  'Olsen' 'Gilnagh' 'Corn' 'Smiljanic' 'Sage' 'Cribb' 'Watt' 'Bengtsson'
#  'Calic' 'Goldsmith' 'Chibnall' 'Baumann' 'Ling' 'Van der hoef' 'Sivola'
#  'Smith' 'Klasen' 'Lefebre' 'Isham' 'Hale' 'Leonard' 'Pernot' 'Becker'
#  'Kink-Heilmann' 'Rood' "O'Brien" 'Romaine' 'Bourke' 'Turcin' 'Pinsky'
#  'Carbines' 'Andersen-Jensen' 'Brown' 'Lurette' 'Mernagh' 'Madigan'
#  'Yrois' 'Vande Walle' 'Johanson' 'Youseff' 'Cohen' 'Strom' 'Albimona'
#  'Carr' 'Blank' 'Ali' 'Cameron' 'Perkin' 'Givard' 'Kiernan' 'Newell'
#  'Honkanen' 'Jacobsohn' 'Bazzani' 'Sunderland' 'Bracken' 'Green' 'Nenkoff'
#  'Hoyt' 'Berglund' 'Mellors' 'Lovell' 'Fahlstrom' 'Larsson' 'Sjostedt'
#  'Leyson' 'Harknett' 'Hold' 'Collyer' 'Pengelly' 'Hunt' 'Murphy'
#  'Coleridge' 'Maenpaa' 'Minahan' 'Lindahl' 'Hamalainen' 'Beckwith'
#  'Carter' 'Reed' 'Stead' 'Lobb' 'Rosblom' 'Touma' 'Thorne' 'Cherry' 'Ward'
#  'Parrish' 'Taussig' 'Harrison' 'Henry' 'Reeves' 'Persson' 'Graham'
#  'Bissette' 'Cairns' 'Tornquist' 'Mellinger' 'Natsch' 'Healy' 'Andrews'
#  'Lindblom' 'Parkes' 'Abbott' 'Duane' 'Olsson' 'de Pelsmaeker' 'Dorking'
#  'Stankovic' 'de Mulder' 'Naidenoff' 'Hosono' 'Connolly' 'Barber' 'Bishop'
#  'Levy' 'Haas' 'Mineff' 'Lewy' 'Hanna' 'Allison' 'Saalfeld' 'Kelly'
#  'McCoy' 'Keane' 'Fleming' 'Penasco y Castellana' 'Abelson' 'Francatelli'
#  'Hays' 'Ryerson' 'Lahtinen' 'Hendekovic' 'Hart' 'Nilsson' 'Moraweck'
#  'Wick' 'Spedden' 'Dennis' 'Danoff' 'Slayter' 'Young' 'Nysveen' 'Ball'
#  'Hippach' 'Partner' 'Frauenthal' 'Denkoff' 'Burns' 'Dahl' 'Blackwell'
#  'Collander' 'Sedgwick' 'Fox' 'Davison' 'Coutts' 'Dimic' 'Odahl'
#  'Williams-Lambert' 'Elias' 'Yousif' 'Vanden Steen' 'Bowerman' 'Funk'
#  'McGovern' 'Mockler' 'del Carlo' 'Barbara' 'Asim' 'Adahl' 'Warren'
#  'Moussa' 'Jermyn' 'Aubart' 'Harder' 'Wiklund' 'Beavan' 'Ringhini'
#  'Landergren' 'Widener' 'Betros' 'Bidois' 'Nakid' 'Tikkanen' 'Plotcharsky'
#  'Davies' 'Buss' 'Sadlier' 'Lehmann' 'Jansson' 'McKane' 'Pain' 'Trout'
#  'Niskanen' 'Adams' 'Oreskovic' 'Gale' 'Widegren' 'Richards' 'Birkeland'
#  'Sdycoff' 'Cunningham' 'Sundman' 'Meek' 'Drew' 'Silven' 'Matthews'
#  'Van Impe' 'Gheorgheff' 'Charters' 'Zimmerman' 'Danbom' 'Wiseman'
#  'Clarke' 'Phillips' 'Flynn' 'Pickard' 'Bjornstrom-Steffansson'
#  'Thorneycroft' 'Louch' 'Kallio' 'Silvey' 'Kvillner' 'Hampe' 'Petterson'
#  'Reynaldo' 'Johannesen-Bratthammer' 'Dodge' 'Seward' 'Baclini' 'Peuchen'
#  'Hagland' 'Foreman' 'Goldenberg' 'Peduzzi' 'Jalsevac' 'Millet' 'Kenyon'
#  'Toomey' "O'Connor" 'Anderson' 'Morley' 'Gee' 'Milling' 'Maisner'
#  'Goncalves' 'Campbell' 'Smart' 'Scanlan' 'Keefe' 'Cacic' 'Jerwan'
#  'Strandberg' 'Clifford' 'Renouf' 'Karlsson' 'Hirvonen' 'Frost' 'Rouse'
#  'Turkula' 'Kent' 'Somerton' 'Windelov' 'Molson' 'Artagaveytia' 'Stanley'
#  'Yousseff' 'Eustis' 'Shellard' 'Svensson' 'Canavan' "O'Sullivan"
#  'Laitinen' 'Maioni' 'Quick' 'Bradley' 'Lang' 'Daly' 'McGough'
#  'Rothschild' 'Coleff' 'Walker' 'Lemore' 'Ryan' 'Angle' 'Pavlovic'
#  'Perreault' 'Vovk' 'Lahoud' 'Kassem' 'Farrell' 'Ridsdale' 'Farthing'
#  'Salonen' 'Hocking' 'Toufik' 'Butt' 'LeRoy' 'Risien' 'Frolicher' 'Crosby'
#  'Beane' 'Douglas' 'Nicholson' 'Padro y Manent' 'Thayer' 'Sharp' 'Leeni'
#  'Ohman' 'Wright' 'Duff Gordon' 'Robbins' 'de Messemaeker' 'Morrow'
#  'Sivic' 'Norman' 'Simmons' 'Meanwell' 'Stoytcheff' 'Doharr' 'Jonsson'
#  'Appleton' 'Rush' 'Patchett' 'Garside' 'Caram' 'Christy' 'Downton' 'Ross'
#  'Paulner' 'Jarvis' 'Frolicher-Stehli' 'Gilinski' 'Murdlin' 'Rintamaki'
#  'Stephenson' 'Elsbury' 'Chapman' 'Leitch' 'Slabenoff' 'Harrington'
#  'Torber' 'Homer' 'Lindell' 'Karaic' 'Daniel' 'Shutes' 'Jardin' 'Horgan'
#  'Brocklebank' 'Herman' 'Gavey' 'Yasbeck' 'Kimball' 'Hansen' 'Bowen'
#  'Sutton' 'Kirkland' 'Longley' 'Bostandyeff' "O'Connell" 'Barkworth'
#  'Lundahl' 'Stahelin-Maeglin' 'Parr' 'Davis' 'Leinonen' 'Jensen'
#  'Sagesser' 'Foo' 'Cor' 'Simonius-Blumer' 'Willey' 'Mitkoff' 'Kalvik'
#  "O'Leary" 'Hegarty' 'Radeff' 'Eitemiller' 'Badt' 'Colley' 'Lindqvist'
#  'Butler' 'Rommetvedt' 'Cook' 'Taylor' 'Davidson' 'Mitchell' 'Wilhelms'
#  'Watson' 'Edvardsson' 'Sawyer' 'Turja' 'Cardeza' 'Peters' 'Hassab'
#  'Olsvigen' 'Dakic' 'Fischer' 'Madill' 'Dick' 'Karun' 'Lam' 'Saad' 'Weir'
#  'Mullens' 'Humblen' 'Astor' 'Silverthorne' 'Gallagher' 'Calderhead'
#  'Cleaver' 'Mayne' 'Klaber' 'Greenberg' 'Soholt' 'Endres' 'Troutt'
#  'McEvoy' 'Gillespie' 'Hodges' 'Chambers' 'Mannion' 'Bryhl' 'Ilmakangas'
#  'Hassan' 'Knight' 'Berriman' 'Troupiansky' 'Lesurer' 'Ivanoff' 'Nankoff'
#  'Hawksford' 'Cavendish' 'McNamee' 'Stranden' 'Sinkkonen' 'Marvin'
#  'Connaghton' 'Wells' 'Moor' 'Vande Velde' 'Jonkoff' 'Carlsson' 'Bailey'
#  'Theobald' 'Rothes' 'Garfirth' 'Nirva' 'Barah' 'Eklund' 'Hogeboom'
#  'Brewe' 'Mangan' 'Gronnestad' 'Lievens' 'Mack' 'Myhrman' 'Tobin'
#  'Emanuel' 'Kilgannon' 'Robert' 'Ayoub' 'Long' 'Johnston' 'Harmer'
#  'Sjoblom' 'Guggenheim' 'Gaskell' 'Dantcheff' 'Otter' 'Leader' 'Osman'
#  'Ibrahim Shawah' 'Ponesell' 'Thomas' 'Hedman' 'Pettersson' 'Alexander'
#  'Lester' 'Slemen' 'Tomlin' 'Fry' 'Heininen' 'Mallet' 'Holm' 'Lulic'
#  'Reuchlin' 'McCormack' 'Stone' 'Augustsson' 'Allum' 'Compton' 'Pasic'
#  'Sirota' 'Chip' 'Marechal' 'Alhomaki' 'Mudd' 'Serepeca' 'Lemberopolous'
#  'Culumovic' 'Abbing' 'Markoff' 'Lines' 'Aks' 'Razi' 'Giles' 'Swift'
#  'Gill' 'Bystrom' 'Duran y More' 'Roebling' 'van Melkebeke' 'Balkic'
#  'Vander Cruyssen' 'Najib' 'Laleff' 'Potter' 'Shelley' 'Markun' 'Dahlberg'
#  'Banfield' 'Sutehall' 'Montvila' 'Behr' 'Dooley']
#  Embarked:  ['S' 'C' 'Q' nan]
#  Sex:  ['male' 'female']
#  Age:  [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

def LabelEncoder (data, feature):
  data[feature] = label_encoder.fit_transform(data[feature])

  return(data)

# %%
from sklearn.preprocessing import OneHotEncoder

def One_Hot_Encoder (data, feature):
  encoded_columns = pd.get_dummies(data[feature])
  return(encoded_columns)

# %%
# Поработаем с признаками 'SibSp' (Кол-во братьев/сестер или супругов, путешествующих с каждым пассажиром) и 'Parch' (Number of parents of children travelling with each passenger): создадим общий признак, размерности семьи:
titanic_df['FamilySize'] = titanic_df['SibSp'] + titanic_df['Parch']
titanic_df[['FamilySize', 'Survived']].groupby(['FamilySize'],).mean().sort_values(by='FamilySize', ascending=False)

titanic_df["Alone"] = titanic_df['FamilySize'] == 0 # Создадим признак, показывающий, кто был в поездке один, без семьи
titanic_df[["Alone", "Survived"]].groupby(['Alone'],).mean().sort_values(by='Alone', ascending=False)
LabelEncoder(titanic_df, 'Alone')# применим кодирование


# Поработаем с признаком 'Fare': создадим признак, показывающий кто к какому классу относится по билетам (билет business-class/ билет middle-class/ билет low-class):
titanic_df['CategoricalFare'] = pd.qcut(titanic_df['Fare'], 4, precision=0)
titanic_df[["CategoricalFare", "Survived"]].groupby(['CategoricalFare'],).mean().sort_values(by='CategoricalFare', ascending=False)

# titanic_df['CategoricalFare'] = titanic_df['CategoricalFare'].apply(rightValue) # установим интервалы

LabelEncoder(titanic_df, 'CategoricalFare')# применим кодирование


# для Ticket, 'Cabin' воспользуемся кодированием через Label Encoder:
LabelEncoder(titanic_df, 'Ticket')
LabelEncoder(titanic_df, 'Cabin')


# Поработаем с признаком 'Embarked' (порт отправления данного пассажира):
titanic_df['Embarked'] = titanic_df['Embarked'].fillna('S') # заполним пустые значения 'S'
titanic_df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean()
LabelEncoder(titanic_df, 'Embarked') # применим кодирование


drop_elements = ['Fare', 'Ticket', 'Cabin', 'SibSp', 'Parch', 'FamilySize']

titanic_df = titanic_df.drop(drop_elements, axis = 1)

titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      Embarked     Family  Alone  CategoricalFare
# 0           2     Braund      0                0
# 1           0    Cumings      0                3
# 2           2  Heikkinen      1                1
# 3           2   Futrelle      0                3
# 4           2      Allen      1                1
# ..        ...        ...    ...              ...
# 886         2   Montvila      1                1
# 887         2     Graham      1                2
# 888         2   Johnston      0                2
# 889         0       Behr      1                2
# 890         1     Dooley      1                0
#
# [891 rows x 10 columns]

# %% [markdown]
# #5. Задания:

# %% [markdown]
# ##A. Сколько пассажиров выжило, а сколько - нет?

# %%
# Survived: Признак, показывающий был ли спасен данный пассажир или нет. 1 означает, что удалось выжить, и 0 - не удалось спастись.
print("Выжило:", titanic_df['Survived'].eq(1).sum(),
      "Умерло:", titanic_df['Survived'].eq(0).sum())
# Out:
# Выжило: 342 Умерло: 549

# %% [markdown]
# ##B. Создайте столбец "IsChild", который равен 1, если возраст меньше 20, и 0 иначе. Для пропущенных значений поведение функции может быть произвольным.

# %%
# Fill missing values in age with random data based on mean and standard variation:
age_avg = titanic_df['Age'].mean()
age_std = titanic_df['Age'].std()
age_null_count = titanic_df['Age'].isnull().sum()
age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size = age_null_count)
titanic_df['Age'][np.isnan(titanic_df['Age'])] = age_null_random_list

titanic_df['IsChild'] = np.where(titanic_df['Age'] <= 20, 1, 0)


titanic_df
# Out:
# <ipython-input-60-5d58de9fa4ec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['Age'][np.isnan(titanic_df['Age'])] = age_null_random_list
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  Embarked  \
# 0                              Braund, Mr. Owen Harris  22.0         2
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         0
# 2                               Heikkinen, Miss. Laina  26.0         2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         2
# 4                             Allen, Mr. William Henry  35.0         2
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         2
# 887                       Graham, Miss. Margaret Edith  19.0         2
# 888           Johnston, Miss. Catherine Helen "Carrie"  32.0         2
# 889                              Behr, Mr. Karl Howell  26.0         0
# 890                                Dooley, Mr. Patrick  32.0         1
#
#         Family  Alone  CategoricalFare  IsChild
# 0       Braund      0                0        0
# 1      Cumings      0                3        0
# 2    Heikkinen      1                1        0
# 3     Futrelle      0                3        0
# 4        Allen      1                1        0
# ..         ...    ...              ...      ...
# 886   Montvila      1                1        0
# 887     Graham      1                2        1
# 888   Johnston      0                2        0
# 889       Behr      1                2        0
# 890     Dooley      1                0        0
#
# [891 rows x 10 columns]

# %% [markdown]
# ##C. Какова доля семей, в которых минимальный возраст меньше 20 (семьи с детьми)?

# %%
# сортируем по одинаковой фамилии (одна семья)
# сортируем по возрасту (диапазон от 0 до 20)
# считаем какую долю составляют эти семьи по отношению ко всем семьям

print(titanic_df[titanic_df['Age'] <= 20]['Family'].count())
# Out:
# 217

# %% [markdown]
# ##D. Какова доля выживших пассажиров из класса 3? А пассажиров из класса 1?

# %%
survived_df = titanic_df[['Pclass', 'Survived']][titanic_df['Survived'] == 1].groupby('Pclass', as_index=False).count()
survived_df['count'] = titanic_df.groupby('Pclass', as_index=False).agg({'Pclass': 'count'})
survived_df['survived_in_class'] = survived_df['Survived'] / survived_df['count']
survived_df
# Out:
#    Pclass  Survived  count  survived_in_class
# 0       1       136    216           0.629630
# 1       2        87    184           0.472826
# 2       3       119    491           0.242363

# %% [markdown]
# ##E. Какова доля выживших женщин из первого класса? А доля выживших мужчин из 3 класса?

# %%
# Поработаем с признаком 'Sex' (пол):
LabelEncoder(titanic_df, 'Sex')
titanic_df["Sex"] = titanic_df['Sex'].astype('int')

titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  Embarked  \
# 0                              Braund, Mr. Owen Harris    1  22.0         2
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0         0
# 2                               Heikkinen, Miss. Laina    0  26.0         2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0         2
# 4                             Allen, Mr. William Henry    1  35.0         2
# ..                                                 ...  ...   ...       ...
# 886                              Montvila, Rev. Juozas    1  27.0         2
# 887                       Graham, Miss. Margaret Edith    0  19.0         2
# 888           Johnston, Miss. Catherine Helen "Carrie"    0   NaN         2
# 889                              Behr, Mr. Karl Howell    1  26.0         0
# 890                                Dooley, Mr. Patrick    1  32.0         1
#
#         Family  Alone  CategoricalFare
# 0       Braund      0                0
# 1      Cumings      0                3
# 2    Heikkinen      1                1
# 3     Futrelle      0                3
# 4        Allen      1                1
# ..         ...    ...              ...
# 886   Montvila      1                1
# 887     Graham      1                2
# 888   Johnston      0                2
# 889       Behr      1                2
# 890     Dooley      1                0
#
# [891 rows x 10 columns]

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           891 non-null    int64
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    int64
#  5   Age              714 non-null    float64
#  6   Embarked         891 non-null    int64
#  7   Family           891 non-null    object
#  8   Alone            891 non-null    int64
#  9   CategoricalFare  891 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 69.7+ KB

# %%
# 0 - женщина
# 1 - мужчина

survived_df = titanic_df[['Pclass', 'Survived']][(titanic_df['Survived'] == 1)& (titanic_df['Sex'] == 0) & (titanic_df["Pclass"] == 1)].groupby('Pclass', as_index=False).count()
survived_df['count'] = titanic_df[(titanic_df['Sex'] == 0) & (titanic_df["Pclass"] == 1)].groupby('Pclass', as_index=False).agg({'Pclass': 'count'})
survived_df['survived_in_class'] = survived_df['Survived'] / survived_df['count']

survived_df
# Out:
#    Pclass  Survived  count  survived_in_class
# 0       1        91     94           0.968085

# %%
survived_df = titanic_df[['Pclass', 'Survived']][(titanic_df['Survived'] == 1)& (titanic_df['Sex'] == 1) & (titanic_df["Pclass"] == 3)].groupby('Pclass', as_index=False).count()
survived_df['count'] = titanic_df[(titanic_df['Sex'] == 1) & (titanic_df["Pclass"] == 3)].groupby('Pclass', as_index=False).agg({'Pclass': 'count'})
survived_df['survived_in_class'] = survived_df['Survived'] / survived_df['count']

survived_df
# Out:
#    Pclass  Survived  count  survived_in_class
# 0       3        47    347           0.135447
